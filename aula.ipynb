# %% [markdown]
# <a href="https://colab.research.google.com/github/Vil-Yo/aula-1/blob/main/aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ('hello Word')
# Out:
# hello Word
